# %% [markdown]
# # Bank transactions Cleaning and Processing

# %% [markdown]
# ### Introduction

# %% [markdown]
# I will be delving into the analysis of my personal bank transactions dataset. The dataset comprises a record of my financial activities over a specified period, encompassing various transactions such as purchases, withdrawals, deposits, and transfers.

# %% [markdown]
# The primary objectives of this analysis are:
#
# - Data Cleaning: Initially, I will focus on cleaning the dataset to ensure its quality and reliability for subsequent analysis. This involves      identifying nd rectifying inconsistencies, missing values, duplicates, and any other anomalies that might affect the integrity of the data.
#
# - Data Processing: Following data cleaning, I will engage in data processing tasks aimed at preparing the dataset for analysis. This involves transforming the data into a structured format conducive to analysis, such as standardizing date formats, categorizing transactions, and aggregating relevant information.

# %%
#import packages needed
import pandas as pd
import numpy as np
from IPython.display import HTML

# %%
#input file
sparkass = pd.read_csv(r"C:\Users\mmoki\OneDrive\Desktop\bank\bank2024.CSV", encoding = 'unicode_escape', index_col=False)

# %%
#view 
sparkass.head(10)
# Out:
#            account_number transaction_date value_date  \
# 0  DE97100500001070816422         29.12.23   29.12.23
# 1  DE97100500001070816422         28.12.23   28.12.23
# 2  DE97100500001070816422         28.12.23   28.12.23
# 3  DE97100500001070816422         28.12.23   28.12.23
# 4  DE97100500001070816422         27.12.23   27.12.23
# 5  DE97100500001070816422         27.12.23   22.12.23
# 6  DE97100500001070816422         22.12.23   22.12.23
# 7  DE97100500001070816422         18.12.23   18.12.23
# 8  DE97100500001070816422         18.12.23   18.12.23
# 9  DE97100500001070816422         18.12.23   18.12.23
#
#               booking_text                          description creditor_id  \
# 0       PAYMENT COMPLETION       EntgeltabINVOICE siehe Anlage          NaN
# 1         REAL-TIME CREDIT                                  NaN         NaN
# 2   FOLLOW-UP DIRECT DEBIT          1031502526009/PP.4428.PP/.          NaN
# 3   FOLLOW-UP DIRECT DEBIT          1031502796418 PP.4428.PP .          NaN
# 4   FOLLOW-UP DIRECT DEBIT  1031443049411/PP.4428.PP/. Flink SE         NaN
# 5          CASH WITHDRAWAL           22.12/21.03UHR 115 896332          NaN
# 6   FOLLOW-UP DIRECT DEBIT  1031420650424/PP.4428.PP/. Flink SE         NaN
# 7             CARD PAYMENT   2023-12-14T20:40 Debitk.2 2026-12          NaN
# 8             CARD PAYMENT   2023-12-17T19:32 Debitk.2 2026-12          NaN
# 9             CARD PAYMENT   2023-12-16T19:23 Debitk.2 2026-12          NaN
#
#   mandate_reference customer_reference  collector_ref  original_amount  \
# 0               NaN                NaN            NaN              NaN
# 1               NaN           3.36E+14            NaN              NaN
# 2               NaN                NaN            NaN              NaN
# 3               NaN                NaN            NaN              NaN
# 4               NaN                NaN            NaN              NaN
# 5               NaN                NaN            NaN              NaN
# 6               NaN                NaN            NaN              NaN
# 7               NaN           6.41E+25            NaN              NaN
# 8               NaN           6.51E+25            NaN              NaN
# 9               NaN           5.42E+25            NaN              NaN
#
#    reimbursement                          beneficiary_name  \
# 0            NaN                                       NaN
# 1            NaN            PayPal (Europe) S.a.r.l et Cie
# 2            NaN                                       NaN
# 3            NaN                                       NaN
# 4            NaN                                  FLINK SE
# 5            NaN               GA NR00002182 BLZ10050000 2
# 6            NaN                                  FLINK SE
# 7            NaN                            EDEKA MEISSNER
# 8            NaN            CINEMAXX MOVIETAINM//BERLIN/DE
# 9            NaN  BOLU LEBENSMITTELHANDELS GMBH//BERLIN/DE
#
#                      iban          bic  amount  currency  info
# 0                       0     10050000   -4.95       NaN   NaN
# 1                     NaN          NaN   49.50       NaN   NaN
# 2                     NaN          NaN   -1.99       NaN   NaN
# 3                     NaN          NaN  -70.35       NaN   NaN
# 4                     NaN          NaN  -28.62       NaN   NaN
# 5                       0     10050000  -20.00       NaN   NaN
# 6                     NaN          NaN  -16.72       NaN   NaN
# 7                     NaN          NaN  -18.27       NaN   NaN
# 8  DE71500400000600178805     COBADEFF  -16.77       NaN   NaN
# 9  DE95100700000650471605  DEUTDEBBXXX  -26.00       NaN   NaN

# %%
#check the datatypes
sparkass.dtypes
# Out:
# account_number         object
# transaction_date       object
# value_date             object
# booking_text           object
# description            object
# creditor_id            object
# mandate_reference      object
# customer_reference     object
# collector_ref         float64
# original_amount       float64
# reimbursement         float64
# beneficiary_name       object
# iban                   object
# bic                    object
# amount                float64
# currency              float64
# info                  float64
# dtype: object

# %%
pd.set_option('display.max_rows', None)  # Show all rows without truncation
pd.set_option('display.max_columns', None)  # Show all columns without truncation

print(sparkass.isnull().sum()) # show for columns that have nulls
# Out:
# account_number          0
# transaction_date        0
# value_date              0
# booking_text            0
# description            23
# creditor_id           836
# mandate_reference     836
# customer_reference    501
# collector_ref         918
# original_amount       918
# reimbursement         918
# beneficiary_name      248
# iban                  383
# bic                   383
# amount                  1
# currency              918
# info                  918
# dtype: int64

# %%
#drop columns that are not needed
sparkass = sparkass.drop(['value_date','account_number', 'creditor_id', 'mandate_reference', 'customer_reference', 'collector_ref', 'original_amount', 'reimbursement', 'iban', 'bic', 'currency','info'], axis=1)

# %%
#rename some columns for better understanding
sparkass = sparkass.rename(columns = {'description': 'transaction_description',
                                      'booking_text': 'transaction_type',
                                     'amount': 'transaction_amount'})

# %%
#Convert transaction_date to datetime format
sparkass['transaction_date'] = pd.to_datetime(sparkass['transaction_date'], format='%d.%m.%y')

# %%
# Convert all string values to lowercase in the DataFrame
sparkass = sparkass.apply(lambda x: x.str.lower() if x.dtype == "object" else x)
sparkass.columns = [column.lower() for column in sparkass.columns]

# %%
pd.set_option('display.max_rows', None)  # Show all rows without truncation
pd.set_option('display.max_columns', None)  # Show all columns without truncation

# %%
#Insert needed columns.
#Add transaction_type_id and category_id
sparkass.insert(0, 'transaction_type_id', 0)
sparkass.insert(1, 'category_id', 0)

# %%
sparkass.head(10)
# Out:
#    transaction_type_id  category_id transaction_date         transaction_type  \
# 0                    0            0       2023-12-29       payment completion
# 1                    0            0       2023-12-28         real-time credit
# 2                    0            0       2023-12-28   follow-up direct debit
# 3                    0            0       2023-12-28   follow-up direct debit
# 4                    0            0       2023-12-27   follow-up direct debit
# 5                    0            0       2023-12-27          cash withdrawal
# 6                    0            0       2023-12-22   follow-up direct debit
# 7                    0            0       2023-12-18             card payment
# 8                    0            0       2023-12-18             card payment
# 9                    0            0       2023-12-18             card payment
#
#                transaction_description  \
# 0       entgeltabinvoice siehe anlage
# 1                                  NaN
# 2          1031502526009/pp.4428.pp/.
# 3          1031502796418 pp.4428.pp .
# 4  1031443049411/pp.4428.pp/. flink se
# 5           22.12/21.03uhr 115 896332
# 6  1031420650424/pp.4428.pp/. flink se
# 7   2023-12-14t20:40 debitk.2 2026-12
# 8   2023-12-17t19:32 debitk.2 2026-12
# 9   2023-12-16t19:23 debitk.2 2026-12
#
#                            beneficiary_name  transaction_amount
# 0                                       NaN               -4.95
# 1            paypal (europe) s.a.r.l et cie               49.50
# 2                                       NaN               -1.99
# 3                                       NaN              -70.35
# 4                                  flink se              -28.62
# 5               ga nr00002182 blz10050000 2              -20.00
# 6                                  flink se              -16.72
# 7                            edeka meissner              -18.27
# 8            cinemaxx movietainm//berlin/de              -16.77
# 9  bolu lebensmittelhandels gmbh//berlin/de              -26.00

# %%
#re order the columns for better reading
new_order = ['transaction_date', 'transaction_type', 'transaction_description', 'transaction_type_id', 'transaction_amount', 'beneficiary_name', 'category_id']
sparkass = sparkass[new_order]

# %%
#The subsequent task involves assigning transaction_type_id and category_id (or a null category) by analyzing the transaction description 
#and amount (whether positive or negative)
sparkass.loc[(sparkass['transaction_type'].str.contains('card')) &
             (sparkass['transaction_amount'] < 0), 
             ['transaction_type_id', 'category_id']] = [1, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('salary')) & 
             (sparkass['transaction_amount'] > 0), 
             ['transaction_type_id', 'category_id']] = [2, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('real-time credit')) & 
             (sparkass['transaction_amount'] > 0), 
             ['transaction_type_id', 'category_id']] = [2, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('giropay')) & 
             (sparkass['transaction_description'].str.contains('kwitt')) &
             (sparkass['transaction_amount'] > 0), 
             ['transaction_type_id', 'category_id']] = [6, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('real-time credit')) &
             (sparkass['beneficiary_name'].str.contains('paypal')) & 
             (sparkass['transaction_amount'] > 0), 
             ['transaction_type_id', 'category_id']] = [3, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('giropay')) & 
             (sparkass['transaction_description'].str.contains('kwitt')) &
             (sparkass['transaction_amount'] < 0), 
             ['transaction_type_id', 'category_id']] = [5, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('cash')) & 
             (sparkass['transaction_amount'] < 0), 
             ['transaction_type_id', 'category_id']] = [7, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('transfer')) & 
             (sparkass['transaction_amount'] > 0), 
             ['transaction_type_id', 'category_id']] = [6, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type'].str.contains('transfer')) & 
             (sparkass['transaction_amount'] < 0), 
             ['transaction_type_id', 'category_id']] = [5, np.nan]

# %%
sparkass.loc[(sparkass['transaction_type_id'] == 0) & (sparkass['transaction_amount'] > 0), 
                   ['transaction_type_id', 'category_id']] = [2, np.nan]

sparkass.loc[(sparkass['transaction_type_id'] == 0) & (sparkass['transaction_amount'] < 0), 
                   ['transaction_type_id', 'category_id']] = [7, np.nan]

# %% [markdown]
# When dealing with category column, I will be focusing only on negative transactions as they represent purchases.

# %%
sparkass['category_id'] = sparkass['category_id'].fillna(0).astype('Int64')

# %%
# list of keywords to check for
keywords = ['edeka', 'rewe', 'lidl', 'euro', 'mueller', 'bolu', 'spatkauf', 'flink', 'gorillas']

# mask to filter rows based on conditions
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)

# Update the 'category_id' column where the conditions are met
sparkass.loc[mask, 'category_id'] = 7

# %%
keywords = ['flink', 'gorillas']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 7

# %%
keywords = ['wolt', 'uber-eats', 'mcdonalds', 'risa', 'restaurant', 'food', 'coffee', 'cafe']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 5

# %%
keywords = ['bvg', 'swapfiets']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 2

# %%
keywords = ['logpay financial']
mask = sparkass['transaction_description'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 2

# %%
keywords = ['welthungerhilfe']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 6

# %%
keywords = ['udemy', 'coursera']
mask = sparkass['transaction_description'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 3

# %%
keywords = ['cinema']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 4

# %%
keywords = ['fit/one', 'apotheke']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 8

# %%
keywords = ['withdrawal']
mask = sparkass['transaction_type'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 9

# %%
keywords = ['invoice', 'recharge.com', 'linkedin', 'entgeltabinvoice', 'aspiegel se', 'mcafee', 'dellmont', 'microsoft', 'recharge']
mask = sparkass['transaction_description'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 10

# %%
keywords = ['etoro']
mask = sparkass['transaction_description'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 12

# %%
keywords = ['etoro']
mask = sparkass['transaction_description'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 12

# %%
keywords = ['rent']
mask = sparkass['beneficiary_name'].str.contains('|'.join(keywords), case=False) & \
       (sparkass['transaction_amount'] < 0)
sparkass.loc[mask, 'category_id'] = 1

# %%
sparkass
# Out:
#     transaction_date         transaction_type  \
# 0         2023-12-29       payment completion
# 1         2023-12-28         real-time credit
# 2         2023-12-28   follow-up direct debit
# 3         2023-12-28   follow-up direct debit
# 4         2023-12-27   follow-up direct debit
# 5         2023-12-27          cash withdrawal
# 6         2023-12-22   follow-up direct debit
# 7         2023-12-18             card payment
# 8         2023-12-18             card payment
# 9         2023-12-18             card payment
# 10        2023-12-18             card payment
# 11        2023-12-15   follow-up direct debit
# 12        2023-12-15   follow-up direct debit
# 13        2023-12-13         real-time credit
# 14        2023-12-08   follow-up direct debit
# 15        2023-12-06  giropay credit overview
# 16        2023-12-06         real-time credit
# 17        2023-12-01       payment completion
# 18        2023-11-30                  invoice
# 19        2023-11-30                   refund
# 20        2023-11-30                  invoice
# 21        2023-11-30                   refund
# 22        2023-11-29   follow-up direct debit
# 23        2023-11-29   follow-up direct debit
# 24        2023-11-28   follow-up direct debit
# 25        2023-11-27   follow-up direct debit
# 26        2023-11-24         real-time credit
# 27        2023-11-24             card payment
# 28        2023-11-23             card payment
# 29        2023-11-22             card payment
# 30        2023-11-21   follow-up direct debit
# 31        2023-11-20             card payment
# 32        2023-11-20   follow-up direct debit
# 33        2023-11-16          credit transfer
# 34        2023-11-15             card payment
# 35        2023-11-15   follow-up direct debit
# 36        2023-11-14   follow-up direct debit
# 37        2023-11-07             card payment
# 38        2023-11-07             card payment
# 39        2023-11-07             card payment
# 40        2023-11-06             card payment
# 41        2023-11-06             card payment
# 42        2023-11-06   follow-up direct debit
# 43        2023-11-03             card payment
# 44        2023-11-02             card payment
# 45        2023-11-01       payment completion
# 46        2023-10-31         real-time credit
# 47        2023-10-31                  invoice
# 48        2023-10-31                   refund
# 49        2023-10-30   follow-up direct debit
# 50        2023-10-24                  invoice
# 51        2023-10-24                   refund
# 52        2023-10-23   follow-up direct debit
# 53        2023-10-23         giropay transfer
# 54        2023-10-17   follow-up direct debit
# 55        2023-10-17                  invoice
# 56        2023-10-17                   refund
# 57        2023-10-16   follow-up direct debit
# 58        2023-10-16                  invoice
# 59        2023-10-16                   refund
# 60        2023-10-13   follow-up direct debit
# 61        2023-10-11          cash withdrawal
# 62        2023-10-10             card payment
# 63        2023-10-10   follow-up direct debit
# 64        2023-10-10   follow-up direct debit
# 65        2023-10-10   follow-up direct debit
# 66        2023-10-09             card payment
# 67        2023-10-06             card payment
# 68        2023-10-04             card payment
# 69        2023-10-04   follow-up direct debit
# 70        2023-10-04   follow-up direct debit
# 71        2023-10-04             card payment
# 72        2023-10-02         real-time credit
# 73        2023-10-02             card payment
# 74        2023-10-02   follow-up direct debit
# 75        2023-10-02                  diploma
# 76        2023-10-02       payment completion
# 77        2023-09-29             card payment
# 78        2023-09-29   follow-up direct debit
# 79        2023-09-27   follow-up direct debit
# 80        2023-09-26   follow-up direct debit
# 81        2023-09-25          cash withdrawal
# 82        2023-09-25   follow-up direct debit
# 83        2023-09-22         giropay transfer
# 84        2023-09-21   follow-up direct debit
# 85        2023-09-20   follow-up direct debit
# 86        2023-09-20   follow-up direct debit
# 87        2023-09-19   follow-up direct debit
# 88        2023-09-19   follow-up direct debit
# 89        2023-09-18             card payment
# 90        2023-09-18             card payment
# 91        2023-09-15   follow-up direct debit
# 92        2023-09-15   follow-up direct debit
# 93        2023-09-15   follow-up direct debit
# 94        2023-09-14          credit transfer
# 95        2023-09-12                  invoice
# 96        2023-09-12                   refund
# 97        2023-09-11   follow-up direct debit
# 98        2023-09-04                  invoice
# 99        2023-09-04                   refund
# 100       2023-09-01   follow-up direct debit
# 101       2023-09-01       payment completion
# 102       2023-08-31   follow-up direct debit
# 103       2023-08-30          cash withdrawal
# 104       2023-08-29   follow-up direct debit
# 105       2023-08-25   follow-up direct debit
# 106       2023-08-22          cash withdrawal
# 107       2023-08-22   follow-up direct debit
# 108       2023-08-22   follow-up direct debit
# 109       2023-08-21   follow-up direct debit
# 110       2023-08-18   follow-up direct debit
# 111       2023-08-17   follow-up direct debit
# 112       2023-08-16   follow-up direct debit
# 113       2023-08-15   follow-up direct debit
# 114       2023-08-15   follow-up direct debit
# 115       2023-08-14   follow-up direct debit
# 116       2023-08-14          cash withdrawal
# 117       2023-08-14          cash withdrawal
# 118       2023-08-11   follow-up direct debit
# 119       2023-08-10             card payment
# 120       2023-08-09             card payment
# 121       2023-08-08   follow-up direct debit
# 122       2023-08-08   follow-up direct debit
# 123       2023-08-08   follow-up direct debit
# 124       2023-08-07             card payment
# 125       2023-08-07             card payment
# 126       2023-08-07   follow-up direct debit
# 127       2023-08-02   follow-up direct debit
# 128       2023-08-01   follow-up direct debit
# 129       2023-08-01   follow-up direct debit
# 130       2023-08-01   follow-up direct debit
# 131       2023-08-01       payment completion
# 132       2023-07-31             card payment
# 133       2023-07-31         real-time credit
# 134       2023-07-28             card payment
# 135       2023-07-28             card payment
# 136       2023-07-26   follow-up direct debit
# 137       2023-07-25          online transfer
# 138       2023-07-25                   salary
# 139       2023-07-24         giropay transfer
# 140       2023-07-24  giropay credit overview
# 141       2023-07-24          cash withdrawal
# 142       2023-07-18          cash withdrawal
# 143       2023-07-18             card payment
# 144       2023-07-18   follow-up direct debit
# 145       2023-07-18   follow-up direct debit
# 146       2023-07-17             card payment
# 147       2023-07-17             customer fee
# 148       2023-07-17             customer fee
# 149       2023-07-17   follow-up direct debit
# 150       2023-07-13          credit transfer
# 151       2023-07-11             customer fee
# 152       2023-07-11   follow-up direct debit
# 153       2023-07-11   follow-up direct debit
# 154       2023-07-06             customer fee
# 155       2023-07-06   follow-up direct debit
# 156       2023-07-04   follow-up direct debit
# 157       2023-07-04   follow-up direct debit
# 158       2023-07-04   follow-up direct debit
# 159       2023-07-03             card payment
# 160       2023-07-03   follow-up direct debit
# 161       2023-07-03                  diploma
# 162       2023-07-03       payment completion
# 163       2023-06-30          online transfer
# 164       2023-06-28   follow-up direct debit
# 165       2023-06-28   follow-up direct debit
# 166       2023-06-27   follow-up direct debit
# 167       2023-06-27   follow-up direct debit
# 168       2023-06-26          online transfer
# 169       2023-06-26                   salary
# 170       2023-06-26             card payment
# 171       2023-06-26             card payment
# 172       2023-06-26             card payment
# 173       2023-06-26             card payment
# 174       2023-06-23             card payment
# 175       2023-06-23             customer fee
# 176       2023-06-21   follow-up direct debit
# 177       2023-06-20   follow-up direct debit
# 178       2023-06-20   follow-up direct debit
# 179       2023-06-20   follow-up direct debit
# 180       2023-06-20   follow-up direct debit
# 181       2023-06-19             card payment
# 182       2023-06-19   follow-up direct debit
# 183       2023-06-16   follow-up direct debit
# 184       2023-06-15   follow-up direct debit
# 185       2023-06-15   follow-up direct debit
# 186       2023-06-13             card payment
# 187       2023-06-13             card payment
# 188       2023-06-13   follow-up direct debit
# 189       2023-06-13             card payment
# 190       2023-06-12   follow-up direct debit
# 191       2023-06-07         giropay transfer
# 192       2023-06-06             customer fee
# 193       2023-06-06             card payment
# 194       2023-06-06   follow-up direct debit
# 195       2023-06-02             customer fee
# 196       2023-06-02             card payment
# 197       2023-06-01   follow-up direct debit
# 198       2023-06-01   follow-up direct debit
# 199       2023-06-01       payment completion
# 200       2023-05-30   follow-up direct debit
# 201       2023-05-30          cash withdrawal
# 202       2023-05-26          online transfer
# 203       2023-05-26                   salary
# 204       2023-05-26   follow-up direct debit
# 205       2023-05-22   follow-up direct debit
# 206       2023-05-22          cash withdrawal
# 207       2023-05-16   follow-up direct debit
# 208       2023-05-15          cash withdrawal
# 209       2023-05-15   follow-up direct debit
# 210       2023-05-15   follow-up direct debit
# 211       2023-05-12             card payment
# 212       2023-05-12             card payment
# 213       2023-05-11   follow-up direct debit
# 214       2023-05-10             card payment
# 215       2023-05-09   follow-up direct debit
# 216       2023-05-08   follow-up direct debit
# 217       2023-05-08          online transfer
# 218       2023-05-08          cash withdrawal
# 219       2023-05-05             card payment
# 220       2023-05-05          cash withdrawal
# 221       2023-05-04             card payment
# 222       2023-05-04             card payment
# 223       2023-05-04             card payment
# 224       2023-05-04             card payment
# 225       2023-05-03   follow-up direct debit
# 226       2023-05-03             card payment
# 227       2023-05-02   follow-up direct debit
# 228       2023-05-02   follow-up direct debit
# 229       2023-05-02       payment completion
# 230       2023-04-26          online transfer
# 231       2023-04-26          online transfer
# 232       2023-04-26                   salary
# 233       2023-04-26   follow-up direct debit
# 234       2023-04-25             customer fee
# 235       2023-04-25   follow-up direct debit
# 236       2023-04-24             card payment
# 237       2023-04-20             customer fee
# 238       2023-04-20   follow-up direct debit
# 239       2023-04-20         real-time credit
# 240       2023-04-19          online transfer
# 241       2023-04-19          online transfer
# 242       2023-04-18   follow-up direct debit
# 243       2023-04-18   follow-up direct debit
# 244       2023-04-17          online transfer
# 245       2023-04-13   follow-up direct debit
# 246       2023-04-11             customer fee
# 247       2023-04-11             card payment
# 248       2023-04-11          credit transfer
# 249       2023-04-11          credit transfer
# 250       2023-04-11             card payment
# 251       2023-04-11             card payment
# 252       2023-04-05   follow-up direct debit
# 253       2023-04-03             card payment
# 254       2023-04-03   follow-up direct debit
# 255       2023-04-03                  diploma
# 256       2023-04-03       payment completion
# 257       2023-03-31          online transfer
# 258       2023-03-31          credit transfer
# 259       2023-03-30         giropay transfer
# 260       2023-03-30             card payment
# 261       2023-03-30   follow-up direct debit
# 262       2023-03-29   follow-up direct debit
# 263       2023-03-27          online transfer
# 264       2023-03-27         giropay transfer
# 265       2023-03-27             card payment
# 266       2023-03-27                   salary
# 267       2023-03-27          cash withdrawal
# 268       2023-03-24         real-time credit
# 269       2023-03-21   follow-up direct debit
# 270       2023-03-21   follow-up direct debit
# 271       2023-03-20             card payment
# 272       2023-03-20             customer fee
# 273       2023-03-17   follow-up direct debit
# 274       2023-03-15   follow-up direct debit
# 275       2023-03-15   follow-up direct debit
# 276       2023-03-13             card payment
# 277       2023-03-13          cash withdrawal
# 278       2023-03-10   follow-up direct debit
# 279       2023-03-09             card payment
# 280       2023-03-07   follow-up direct debit
# 281       2023-03-03             customer fee
# 282       2023-03-03   follow-up direct debit
# 283       2023-03-03          online transfer
# 284       2023-03-02   follow-up direct debit
# 285       2023-03-01   follow-up direct debit
# 286       2023-03-01       payment completion
# 287       2023-02-27             card payment
# 288       2023-02-27             card payment
# 289       2023-02-27       real-time transfer
# 290       2023-02-27          online transfer
# 291       2023-02-24          cash withdrawal
# 292       2023-02-24                   salary
# 293       2023-02-24         real-time credit
# 294       2023-02-24                  invoice
# 295       2023-02-24                   refund
# 296       2023-02-23   follow-up direct debit
# 297       2023-02-23                  invoice
# 298       2023-02-17          cash withdrawal
# 299       2023-02-17  giropay credit overview
# 300       2023-02-16   follow-up direct debit
# 301       2023-02-16   follow-up direct debit
# 302       2023-02-15   follow-up direct debit
# 303       2023-02-13   follow-up direct debit
# 304       2023-02-08   follow-up direct debit
# 305       2023-02-07   follow-up direct debit
# 306       2023-02-06   follow-up direct debit
# 307       2023-02-01          cash withdrawal
# 308       2023-02-01          online transfer
# 309       2023-02-01   follow-up direct debit
# 310       2023-02-01   follow-up direct debit
# 311       2023-02-01       payment completion
# 312       2023-01-31   follow-up direct debit
# 313       2023-01-31          cash withdrawal
# 314       2023-01-31          credit transfer
# 315       2023-01-30             card payment
# 316       2023-01-30   follow-up direct debit
# 317       2023-01-27   follow-up direct debit
# 318       2023-01-26                   salary
# 319       2023-01-25          cash withdrawal
# 320       2023-01-25   follow-up direct debit
# 321       2023-01-24   follow-up direct debit
# 322       2023-01-23          cash withdrawal
# 323       2023-01-23   follow-up direct debit
# 324       2023-01-20   follow-up direct debit
# 325       2023-01-19             card payment
# 326       2023-01-19   follow-up direct debit
# 327       2023-01-19   follow-up direct debit
# 328       2023-01-18             card payment
# 329       2023-01-18             card payment
# 330       2023-01-18          cash withdrawal
# 331       2023-01-17   follow-up direct debit
# 332       2023-01-16   follow-up direct debit
# 333       2023-01-16          cash withdrawal
# 334       2023-01-13          credit transfer
# 335       2023-01-13   follow-up direct debit
# 336       2023-01-12          cash withdrawal
# 337       2023-01-11          cash withdrawal
# 338       2023-01-11          credit transfer
# 339       2023-01-11   follow-up direct debit
# 340       2023-01-10   follow-up direct debit
# 341       2023-01-09             card payment
# 342       2023-01-09   follow-up direct debit
# 343       2023-01-09          cash withdrawal
# 344       2023-01-05          cash withdrawal
# 345       2023-01-05   follow-up direct debit
# 346       2023-01-04          credit transfer
# 347       2023-01-03                  invoice
# 348       2023-01-02             card payment
# 349       2023-01-02   follow-up direct debit
# 350       2023-01-02          cash withdrawal
# 351       2022-12-30             customer fee
# 352       2022-12-30          online transfer
# 353       2022-12-30       payment completion
# 354       2022-12-28             card payment
# 355       2022-12-28             card payment
# 356       2022-12-28             card payment
# 357       2022-12-27          credit transfer
# 358       2022-12-27             card payment
# 359       2022-12-27   follow-up direct debit
# 360       2022-12-27          cash withdrawal
# 361       2022-12-23             card payment
# 362       2022-12-23   follow-up direct debit
# 363       2022-12-21             card payment
# 364       2022-12-19          cash withdrawal
# 365       2022-12-19             card payment
# 366       2022-12-19       real-time transfer
# 367       2022-12-19          cash withdrawal
# 368       2022-12-16   follow-up direct debit
# 369       2022-12-16   follow-up direct debit
# 370       2022-12-15          cash withdrawal
# 371       2022-12-15   international transfer
# 372       2022-12-15   follow-up direct debit
# 373       2022-12-15   follow-up direct debit
# 374       2022-12-14   follow-up direct debit
# 375       2022-12-13             card payment
# 376       2022-12-13   follow-up direct debit
# 377       2022-12-13   follow-up direct debit
# 378       2022-12-13   follow-up direct debit
# 379       2022-12-12             customer fee
# 380       2022-12-12   follow-up direct debit
# 381       2022-12-12          cash withdrawal
# 382       2022-12-12          credit transfer
# 383       2022-12-09          cash withdrawal
# 384       2022-12-06          cash withdrawal
# 385       2022-12-06             card payment
# 386       2022-12-06   follow-up direct debit
# 387       2022-12-06             card payment
# 388       2022-12-05             card payment
# 389       2022-12-05             card payment
# 390       2022-12-05   follow-up direct debit
# 391       2022-12-01          online transfer
# 392       2022-12-01          credit transfer
# 393       2022-12-01   follow-up direct debit
# 394       2022-12-01       payment completion
# 395       2022-11-30   follow-up direct debit
# 396       2022-11-29             card payment
# 397       2022-11-28             card payment
# 398       2022-11-28             card payment
# 399       2022-11-28   follow-up direct debit
# 400       2022-11-25          cash withdrawal
# 401       2022-11-25             card payment
# 402       2022-11-24   follow-up direct debit
# 403       2022-11-24   follow-up direct debit
# 404       2022-11-24   follow-up direct debit
# 405       2022-11-24          cash withdrawal
# 406       2022-11-23          credit transfer
# 407       2022-11-22             card payment
# 408       2022-11-22   follow-up direct debit
# 409       2022-11-21             card payment
# 410       2022-11-21             card payment
# 411       2022-11-18          cash withdrawal
# 412       2022-11-16             card payment
# 413       2022-11-16             card payment
# 414       2022-11-16   follow-up direct debit
# 415       2022-11-15   follow-up direct debit
# 416       2022-11-15   follow-up direct debit
# 417       2022-11-14             card payment
# 418       2022-11-14             card payment
# 419       2022-11-14             card payment
# 420       2022-11-14             card payment
# 421       2022-11-14          cash withdrawal
# 422       2022-11-14          online transfer
# 423       2022-11-11                   salary
# 424       2022-11-11   follow-up direct debit
# 425       2022-11-10         real-time credit
# 426       2022-11-10             card payment
# 427       2022-11-09             card payment
# 428       2022-11-08          cash withdrawal
# 429       2022-11-08             card payment
# 430       2022-11-07          online transfer
# 431       2022-11-07  giropay credit overview
# 432       2022-11-04   follow-up direct debit
# 433       2022-11-03         giropay transfer
# 434       2022-11-01   follow-up direct debit
# 435       2022-11-01   follow-up direct debit
# 436       2022-11-01   follow-up direct debit
# 437       2022-11-01       payment completion
# 438       2022-10-31          online transfer
# 439       2022-10-31             card payment
# 440       2022-10-31             card payment
# 441       2022-10-28             card payment
# 442       2022-10-27   follow-up direct debit
# 443       2022-10-25   follow-up direct debit
# 444       2022-10-25   follow-up direct debit
# 445       2022-10-25   follow-up direct debit
# 446       2022-10-24          credit transfer
# 447       2022-10-20   follow-up direct debit
# 448       2022-10-19          cash withdrawal
# 449       2022-10-19          online transfer
# 450       2022-10-19             card payment
# 451       2022-10-19          credit transfer
# 452       2022-10-18   follow-up direct debit
# 453       2022-10-17             card payment
# 454       2022-10-17             card payment
# 455       2022-10-17             card payment
# 456       2022-10-17             card payment
# 457       2022-10-17             card payment
# 458       2022-10-17   follow-up direct debit
# 459       2022-10-17          cash withdrawal
# 460       2022-10-14   follow-up direct debit
# 461       2022-10-13         giropay transfer
# 462       2022-10-13          online transfer
# 463       2022-10-13                   salary
# 464       2022-10-13             card payment
# 465       2022-10-12             card payment
# 466       2022-10-10             card payment
# 467       2022-10-10   follow-up direct debit
# 468       2022-10-07             card payment
# 469       2022-10-06             card payment
# 470       2022-10-06             card payment
# 471       2022-10-06   follow-up direct debit
# 472       2022-10-05   follow-up direct debit
# 473       2022-10-05   follow-up direct debit
# 474       2022-10-04   follow-up direct debit
# 475       2022-10-04             card payment
# 476       2022-10-04             card payment
# 477       2022-10-04       payment completion
# 478       2022-10-04          cash withdrawal
# 479       2022-09-30             card payment
# 480       2022-09-30   follow-up direct debit
# 481       2022-09-29             card payment
# 482       2022-09-29   follow-up direct debit
# 483       2022-09-28          cash withdrawal
# 484       2022-09-28   follow-up direct debit
# 485       2022-09-27             card payment
# 486       2022-09-27             card payment
# 487       2022-09-26             card payment
# 488       2022-09-26             card payment
# 489       2022-09-26          credit transfer
# 490       2022-09-21          online transfer
# 491       2022-09-21             card payment
# 492       2022-09-21   follow-up direct debit
# 493       2022-09-20          cash withdrawal
# 494       2022-09-20   follow-up direct debit
# 495       2022-09-19          credit transfer
# 496       2022-09-19             card payment
# 497       2022-09-19          cash withdrawal
# 498       2022-09-19             card payment
# 499       2022-09-19             card payment
# 500       2022-09-19             card payment
# 501       2022-09-19             card payment
# 502       2022-09-16          cash withdrawal
# 503       2022-09-15             card payment
# 504       2022-09-15   follow-up direct debit
# 505       2022-09-15   follow-up direct debit
# 506       2022-09-14          cash withdrawal
# 507       2022-09-14             card payment
# 508       2022-09-14             card payment
# 509       2022-09-13          online transfer
# 510       2022-09-13                   salary
# 511       2022-09-13   follow-up direct debit
# 512       2022-09-13             card payment
# 513       2022-09-13   follow-up direct debit
# 514       2022-09-12             card payment
# 515       2022-09-12             card payment
# 516       2022-09-12             card payment
# 517       2022-09-12             card payment
# 518       2022-09-12          cash withdrawal
# 519       2022-09-09         real-time credit
# 520       2022-09-09          credit transfer
# 521       2022-09-09             card payment
# 522       2022-09-09             card payment
# 523       2022-09-08             card payment
# 524       2022-09-08             card payment
# 525       2022-09-07             card payment
# 526       2022-09-07             card payment
# 527       2022-09-07          online transfer
# 528       2022-09-06          cash withdrawal
# 529       2022-09-06         real-time credit
# 530       2022-09-06             card payment
# 531       2022-09-06             card payment
# 532       2022-09-06             card payment
# 533       2022-09-06   follow-up direct debit
# 534       2022-09-05          cash withdrawal
# 535       2022-09-05             card payment
# 536       2022-09-05             card payment
# 537       2022-09-05   follow-up direct debit
# 538       2022-09-05         real-time credit
# 539       2022-09-05          cash withdrawal
# 540       2022-09-01          online transfer
# 541       2022-09-01   follow-up direct debit
# 542       2022-09-01                  diploma
# 543       2022-09-01       payment completion
# 544       2022-08-31             card payment
# 545       2022-08-31   follow-up direct debit
# 546       2022-08-30             card payment
# 547       2022-08-30             card payment
# 548       2022-08-30          cash withdrawal
# 549       2022-08-29             card payment
# 550       2022-08-29             card payment
# 551       2022-08-29             card payment
# 552       2022-08-29   follow-up direct debit
# 553       2022-08-29             card payment
# 554       2022-08-25             card payment
# 555       2022-08-25             card payment
# 556       2022-08-25             card payment
# 557       2022-08-25   follow-up direct debit
# 558       2022-08-24             card payment
# 559       2022-08-23             card payment
# 560       2022-08-23             card payment
# 561       2022-08-23          credit transfer
# 562       2022-08-22             card payment
# 563       2022-08-22          cash withdrawal
# 564       2022-08-22          cash withdrawal
# 565       2022-08-22          cash withdrawal
# 566       2022-08-19         real-time credit
# 567       2022-08-19             card payment
# 568       2022-08-19             card payment
# 569       2022-08-18          online transfer
# 570       2022-08-18          credit transfer
# 571       2022-08-17             card payment
# 572       2022-08-16   follow-up direct debit
# 573       2022-08-16   follow-up direct debit
# 574       2022-08-16   follow-up direct debit
# 575       2022-08-16   follow-up direct debit
# 576       2022-08-15   follow-up direct debit
# 577       2022-08-15   follow-up direct debit
# 578       2022-08-15          cash withdrawal
# 579       2022-08-12   follow-up direct debit
# 580       2022-08-11          online transfer
# 581       2022-08-11                   salary
# 582       2022-08-10   follow-up direct debit
# 583       2022-08-09          cash withdrawal
# 584       2022-08-09  giropay credit overview
# 585       2022-08-09         real-time credit
# 586       2022-08-09          online transfer
# 587       2022-08-09   follow-up direct debit
# 588       2022-08-09   follow-up direct debit
# 589       2022-08-09   follow-up direct debit
# 590       2022-08-09   follow-up direct debit
# 591       2022-08-08             card payment
# 592       2022-08-08          credit transfer
# 593       2022-08-08   follow-up direct debit
# 594       2022-08-08          online transfer
# 595       2022-08-08          online transfer
# 596       2022-08-08         giropay transfer
# 597       2022-08-08     bargeldeinzahlung sb
# 598       2022-08-05         real-time credit
# 599       2022-08-03  giropay credit overview
# 600       2022-08-03         real-time credit
# 601       2022-08-03   follow-up direct debit
# 602       2022-08-01          cash withdrawal
# 603       2022-08-01             card payment
# 604       2022-08-01   follow-up direct debit
# 605       2022-08-01             card payment
# 606       2022-08-01          online transfer
# 607       2022-08-01       payment completion
# 608       2022-07-28          cash withdrawal
# 609       2022-07-28             card payment
# 610       2022-07-26             card payment
# 611       2022-07-26             card payment
# 612       2022-07-25             card payment
# 613       2022-07-25             card payment
# 614       2022-07-21          cash withdrawal
# 615       2022-07-20             card payment
# 616       2022-07-19          credit transfer
# 617       2022-07-19             card payment
# 618       2022-07-19             card payment
# 619       2022-07-18          cash withdrawal
# 620       2022-07-18         giropay transfer
# 621       2022-07-15             card payment
# 622       2022-07-15   follow-up direct debit
# 623       2022-07-15   follow-up direct debit
# 624       2022-07-14             customer fee
# 625       2022-07-14             card payment
# 626       2022-07-14             card payment
# 627       2022-07-14             card payment
# 628       2022-07-13          online transfer
# 629       2022-07-13          online transfer
# 630       2022-07-13                   salary
# 631       2022-07-13             card payment
# 632       2022-07-13             card payment
# 633       2022-07-12             card payment
# 634       2022-07-12             direct debit
# 635       2022-07-11             card payment
# 636       2022-07-11          credit transfer
# 637       2022-07-11             card payment
# 638       2022-07-11             card payment
# 639       2022-07-11             card payment
# 640       2022-07-11   follow-up direct debit
# 641       2022-07-07             card payment
# 642       2022-07-07          online transfer
# 643       2022-07-05   follow-up direct debit
# 644       2022-07-04          credit transfer
# 645       2022-07-04          online transfer
# 646       2022-07-04          cash withdrawal
# 647       2022-07-01   follow-up direct debit
# 648       2022-07-01                  diploma
# 649       2022-07-01       payment completion
# 650       2022-06-30          online transfer
# 651       2022-06-30          credit transfer
# 652       2022-06-30             card payment
# 653       2022-06-30             card payment
# 654       2022-06-30             card payment
# 655       2022-06-29             card payment
# 656       2022-06-29             card payment
# 657       2022-06-29             card payment
# 658       2022-06-28          credit transfer
# 659       2022-06-28             card payment
# 660       2022-06-28             card payment
# 661       2022-06-28             card payment
# 662       2022-06-28             card payment
# 663       2022-06-28             card payment
# 664       2022-06-28             card payment
# 665       2022-06-27             card payment
# 666       2022-06-27             card payment
# 667       2022-06-24             card payment
# 668       2022-06-24             card payment
# 669       2022-06-24             card payment
# 670       2022-06-23          cash withdrawal
# 671       2022-06-22             card payment
# 672       2022-06-22             card payment
# 673       2022-06-21             card payment
# 674       2022-06-21             card payment
# 675       2022-06-20             card payment
# 676       2022-06-20             card payment
# 677       2022-06-20             card payment
# 678       2022-06-20   follow-up direct debit
# 679       2022-06-20             card payment
# 680       2022-06-20             card payment
# 681       2022-06-20         giropay transfer
# 682       2022-06-20          cash withdrawal
# 683       2022-06-16             card payment
# 684       2022-06-16             card payment
# 685       2022-06-15         giropay transfer
# 686       2022-06-15          online transfer
# 687       2022-06-15          cash withdrawal
# 688       2022-06-15   follow-up direct debit
# 689       2022-06-15   follow-up direct debit
# 690       2022-06-15   follow-up direct debit
# 691       2022-06-14             card payment
# 692       2022-06-14             card payment
# 693       2022-06-13          cash withdrawal
# 694       2022-06-13          online transfer
# 695       2022-06-13                   salary
# 696       2022-06-13          credit transfer
# 697       2022-06-13             card payment
# 698       2022-06-13   follow-up direct debit
# 699       2022-06-13          cash withdrawal
# 700       2022-06-13          cash withdrawal
# 701       2022-06-13          cash withdrawal
# 702       2022-06-13                  invoice
# 703       2022-06-13                   refund
# 704       2022-06-13                  invoice
# 705       2022-06-13                   refund
# 706       2022-06-10             card payment
# 707       2022-06-10   follow-up direct debit
# 708       2022-06-10   follow-up direct debit
# 709       2022-06-09  giropay credit overview
# 710       2022-06-09             card payment
# 711       2022-06-08         giropay transfer
# 712       2022-06-08             card payment
# 713       2022-06-08             card payment
# 714       2022-06-07   follow-up direct debit
# 715       2022-06-07             card payment
# 716       2022-06-07             card payment
# 717       2022-06-07             card payment
# 718       2022-06-07             card payment
# 719       2022-06-01             card payment
# 720       2022-06-01   follow-up direct debit
# 721       2022-06-01       payment completion
# 722       2022-05-31             card payment
# 723       2022-05-31             card payment
# 724       2022-05-31   follow-up direct debit
# 725       2022-05-31   follow-up direct debit
# 726       2022-05-31   follow-up direct debit
# 727       2022-05-30          cash withdrawal
# 728       2022-05-30  giropay credit overview
# 729       2022-05-30  giropay credit overview
# 730       2022-05-30          cash withdrawal
# 731       2022-05-30         real-time credit
# 732       2022-05-27         real-time credit
# 733       2022-05-25             card payment
# 734       2022-05-25             card payment
# 735       2022-05-25             card payment
# 736       2022-05-24          cash withdrawal
# 737       2022-05-24             card payment
# 738       2022-05-23             card payment
# 739       2022-05-23             card payment
# 740       2022-05-23             card payment
# 741       2022-05-23          cash withdrawal
# 742       2022-05-23         giropay transfer
# 743       2022-05-23       real-time transfer
# 744       2022-05-23          online transfer
# 745       2022-05-23          online transfer
# 746       2022-05-20          credit transfer
# 747       2022-05-20             card payment
# 748       2022-05-20             card payment
# 749       2022-05-19             card payment
# 750       2022-05-19             card payment
# 751       2022-05-18         giropay transfer
# 752       2022-05-18   follow-up direct debit
# 753       2022-05-17       real-time transfer
# 754       2022-05-17   follow-up direct debit
# 755       2022-05-17             card payment
# 756       2022-05-16             card payment
# 757       2022-05-16             card payment
# 758       2022-05-16             card payment
# 759       2022-05-16             card payment
# 760       2022-05-16          credit transfer
# 761       2022-05-16   follow-up direct debit
# 762       2022-05-13          cash withdrawal
# 763       2022-05-13         real-time credit
# 764       2022-05-13          online transfer
# 765       2022-05-13             card payment
# 766       2022-05-12          cash withdrawal
# 767       2022-05-11                   salary
# 768       2022-05-10   follow-up direct debit
# 769       2022-05-10   follow-up direct debit
# 770       2022-05-09          cash withdrawal
# 771       2022-05-09  giropay credit overview
# 772       2022-05-05          cash withdrawal
# 773       2022-05-03          cash withdrawal
# 774       2022-05-03  giropay credit overview
# 775       2022-05-02             card payment
# 776       2022-05-02             card payment
# 777       2022-05-02   follow-up direct debit
# 778       2022-05-02          cash withdrawal
# 779       2022-05-02          online transfer
# 780       2022-05-02          cash withdrawal
# 781       2022-05-02          cash withdrawal
# 782       2022-05-02       payment completion
# 783       2022-04-29             card payment
# 784       2022-04-29             card payment
# 785       2022-04-26             card payment
# 786       2022-04-26   follow-up direct debit
# 787       2022-04-26   follow-up direct debit
# 788       2022-04-25             card payment
# 789       2022-04-25   follow-up direct debit
# 790       2022-04-22   follow-up direct debit
# 791       2022-04-22   follow-up direct debit
# 792       2022-04-22   follow-up direct debit
# 793       2022-04-20          cash withdrawal
# 794       2022-04-20             card payment
# 795       2022-04-20             card payment
# 796       2022-04-20   follow-up direct debit
# 797       2022-04-19             card payment
# 798       2022-04-19          credit transfer
# 799       2022-04-19             card payment
# 800       2022-04-19             card payment
# 801       2022-04-19   follow-up direct debit
# 802       2022-04-19   follow-up direct debit
# 803       2022-04-19          cash withdrawal
# 804       2022-04-14          online transfer
# 805       2022-04-13                   salary
# 806       2022-04-13          cash withdrawal
# 807       2022-04-11   follow-up direct debit
# 808       2022-04-07  giropay credit overview
# 809       2022-04-07   follow-up direct debit
# 810       2022-04-07   follow-up direct debit
# 811       2022-04-06          cash withdrawal
# 812       2022-04-06   follow-up direct debit
# 813       2022-04-06   follow-up direct debit
# 814       2022-04-06   follow-up direct debit
# 815       2022-04-06             card payment
# 816       2022-04-06         giropay transfer
# 817       2022-04-05   follow-up direct debit
# 818       2022-04-05             card payment
# 819       2022-04-04             card payment
# 820       2022-04-04             card payment
# 821       2022-04-04             card payment
# 822       2022-04-04          online transfer
# 823       2022-04-01   follow-up direct debit
# 824       2022-04-01                  diploma
# 825       2022-04-01       payment completion
# 826       2022-03-31             card payment
# 827       2022-03-30  giropay credit overview
# 828       2022-03-30             card payment
# 829       2022-03-30             card payment
# 830       2022-03-30             card payment
# 831       2022-03-30             card payment
# 832       2022-03-30   follow-up direct debit
# 833       2022-03-29             card payment
# 834       2022-03-29          online transfer
# 835       2022-03-28             card payment
# 836       2022-03-28             card payment
# 837       2022-03-25         giropay transfer
# 838       2022-03-24             card payment
# 839       2022-03-23   follow-up direct debit
# 840       2022-03-22   follow-up direct debit
# 841       2022-03-22             card payment
# 842       2022-03-22             card payment
# 843       2022-03-22             card payment
# 844       2022-03-22             card payment
# 845       2022-03-21             card payment
# 846       2022-03-21             card payment
# 847       2022-03-21             card payment
# 848       2022-03-21             card payment
# 849       2022-03-21             card payment
# 850       2022-03-21             card payment
# 851       2022-03-21             card payment
# 852       2022-03-21   follow-up direct debit
# 853       2022-03-21          cash withdrawal
# 854       2022-03-18             card payment
# 855       2022-03-18   follow-up direct debit
# 856       2022-03-18             card payment
# 857       2022-03-17             card payment
# 858       2022-03-17   follow-up direct debit
# 859       2022-03-16             card payment
# 860       2022-03-16       real-time transfer
# 861       2022-03-15             card payment
# 862       2022-03-15   follow-up direct debit
# 863       2022-03-15             card payment
# 864       2022-03-15             card payment
# 865       2022-03-14             card payment
# 866       2022-03-14          credit transfer
# 867       2022-03-14             card payment
# 868       2022-03-14             card payment
# 869       2022-03-11          online transfer
# 870       2022-03-11          cash withdrawal
# 871       2022-03-11                   salary
# 872       2022-03-11          credit transfer
# 873       2022-03-10   follow-up direct debit
# 874       2022-03-07          cash withdrawal
# 875       2022-03-07         real-time credit
# 876       2022-03-07          credit transfer
# 877       2022-03-07         giropay transfer
# 878       2022-03-02    cash withdrawal kasse
# 879       2022-03-01          credit transfer
# 880       2022-03-01          credit transfer
# 881       2022-03-01          credit transfer
# 882       2022-03-01   follow-up direct debit
# 883       2022-03-01       payment completion
# 884       2022-02-28          online transfer
# 885       2022-02-25          online transfer
# 886       2022-02-25         real-time credit
# 887       2022-02-25   follow-up direct debit
# 888       2022-02-24   follow-up direct debit
# 889       2022-02-24   follow-up direct debit
# 890       2022-02-24   follow-up direct debit
# 891       2022-02-24   follow-up direct debit
# 892       2022-02-23   follow-up direct debit
# 893       2022-02-22          online transfer
# 894       2022-02-22   follow-up direct debit
# 895       2022-02-22   follow-up direct debit
# 896       2022-02-22   follow-up direct debit
# 897       2022-02-21         giropay transfer
# 898       2022-02-21          online transfer
# 899       2022-02-21         real-time credit
# 900       2022-02-18   follow-up direct debit
# 901       2022-02-17   follow-up direct debit
# 902       2022-02-17   follow-up direct debit
# 903       2022-02-17   follow-up direct debit
# 904       2022-02-17                  invoice
# 905       2022-02-15          credit transfer
# 906       2022-02-15   follow-up direct debit
# 907       2022-02-15          online transfer
# 908       2022-02-14          credit transfer
# 909       2022-02-14          online transfer
# 910       2022-02-11                   salary
# 911       2022-02-11   follow-up direct debit
# 912       2022-02-10   follow-up direct debit
# 913       2022-02-09    cash withdrawal kasse
# 914       2022-02-07     bargeldeinzahlung sb
# 915       2022-02-03          online transfer
# 916       2022-02-03          online transfer
# 917       2022-02-01   follow-up direct debit
#
#                                transaction_description  transaction_type_id  \
# 0                       entgeltabinvoice siehe anlage                     7
# 1                                                  NaN                    3
# 2                          1031502526009/pp.4428.pp/.                     7
# 3                          1031502796418 pp.4428.pp .                     7
# 4                  1031443049411/pp.4428.pp/. flink se                    7
# 5                           22.12/21.03uhr 115 896332                     7
# 6                  1031420650424/pp.4428.pp/. flink se                    7
# 7                   2023-12-14t20:40 debitk.2 2026-12                     1
# 8                   2023-12-17t19:32 debitk.2 2026-12                     1
# 9                   2023-12-16t19:23 debitk.2 2026-12                     1
# 10                  2023-12-15t21:10 debitk.2 2026-12                     1
# 11                 1031266411713/pp.4428.pp/. flink se                    7
# 12   psn0071864851...........danke fuer ihre spende...                    7
# 13                                                 NaN                    3
# 14                 1031110583702/pp.4428.pp/. flink se                    7
# 15                         / giropay i kwitt (5b7553)                     6
# 16                                                 NaN                    3
# 17                      entgeltabinvoice siehe anlage                     7
# 18                invoice rückgabe lastschrift über 16                    7
# 19                 1030893632315/pp.4428.pp/. flink se                    2
# 20                invoice rückgabe lastschrift über 24                    7
# 21     1030900041216/. recharge.com international b.v.                    2
# 22     1030900041216/. recharge.com international b.v.                    7
# 23                 1030893632315/pp.4428.pp/. flink se                    7
# 24                         1030831041540/pp.4428.pp/.                     7
# 25                 1030812486091/pp.4428.pp/. flink se                    7
# 26                                                 NaN                    3
# 27                  2023-11-22t17:27 debitk.2 2026-12                     1
# 28                  2023-11-22t18:14 debitk.2 2026-12                     1
# 29                  2023-11-21t19:43 debitk.2 2026-12                     1
# 30                 1030739911945/pp.4428.pp/. flink se                    7
# 31                  2023-11-17t21:37 debitk.2 2026-12                     1
# 32                 1030663891462 pp.4428.pp . flink se                    2
# 33              pp.4428.pp abbuchung vom paypal-konto                     6
# 34                  2023-11-14t18:58 debitk.2 2026-12                     1
# 35   psn0071864851...........danke fuer ihre spende...                    7
# ...
# 76            10
# 77             7
# 78             5
# 79             7
# 80             7
# 81             9
# 82             0
# 83             0
# 84             2
# 85            10
# 86             7
# 87            10
# 88            10
# 89             7
# 90             0
# 91             0
# 92             0
# 93             6
# 94             0
# 95            10
# 96             0
# 97             0
# 98            10
# 99             0
# 100           10
# 101           10
# 102            0
# 103            9
# 104            0
# 105           10
# 106            9
# 107            7
# 108            5
# 109            7
# 110            5
# 111            7
# 112            7
# 113           10
# 114            6
# 115            7
# 116            9
# 117            9
# 118           10
# 119            7
# 120            7
# 121            0
# 122            0
# 123           10
# 124            2
# 125            7
# 126            0
# 127            0
# 128            0
# 129           10
# 130            7
# 131           10
# 132            0
# 133            0
# 134            7
# 135            0
# 136           10
# 137           12
# 138            0
# 139            0
# 140            0
# 141            9
# 142            9
# 143            8
# 144            0
# 145            0
# 146            7
# 147            0
# 148            0
# 149            6
# 150            0
# 151            0
# 152            7
# 153            7
# 154            0
# 155            7
# 156           10
# 157            7
# 158            0
# 159            7
# 160            8
# 161            0
# 162           10
# 163            0
# 164           12
# 165            7
# 166            0
# 167            0
# 168            0
# 169            0
# 170            7
# 171            7
# 172            0
# 173            0
# 174            0
# 175            0
# 176            2
# 177           10
# 178            7
# 179            5
# 180            5
# 181            0
# 182            5
# 183           12
# 184            7
# 185            6
# 186            0
# 187            0
# 188           12
# 189            0
# 190            0
# 191            0
# 192            0
# 193            0
# 194            7
# 195            0
# 196            0
# 197            8
# 198            7
# 199           10
# 200            0
# 201            9
# 202            0
# 203            0
# 204            7
# 205            7
# 206            9
# 207            7
# 208            9
# 209            6
# 210            7
# 211            0
# 212            0
# 213            0
# 214            7
# 215            7
# 216            0
# 217            0
# 218            9
# 219            5
# 220            9
# 221            5
# 222            5
# 223            7
# 224            0
# 225           10
# 226            5
# 227            8
# 228            0
# 229           10
# 230            0
# 231            0
# 232            0
# 233            7
# 234            0
# 235           10
# 236            7
# 237            0
# 238            0
# 239            0
# 240            0
# 241            0
# 242            0
# 243            6
# 244            0
# 245            7
# 246            0
# 247            0
# 248            0
# 249            0
# 250            0
# 251            0
# 252            7
# 253            0
# 254            8
# 255           10
# 256           10
# 257            0
# 258            0
# 259            1
# 260            7
# 261            7
# 262            0
# 263            0
# 264            0
# 265            7
# 266            0
# 267            9
# 268            0
# 269           10
# 270           10
# 271            2
# 272            0
# 273            0
# 274            7
# 275            6
# 276            7
# 277            9
# 278            0
# 279            7
# 280            0
# 281            0
# 282            0
# 283            0
# 284            0
# 285            8
# 286           10
# 287            7
# 288            7
# 289            0
# 290            0
# 291            9
# 292            0
# 293            0
# 294           10
# 295            0
# 296            7
# 297           10
# 298            9
# 299            0
# 300           10
# 301           10
# 302            6
# 303           10
# 304            0
# 305           10
# 306            0
# 307            9
# 308            1
# 309            8
# 310            2
# 311           10
# 312            2
# 313            9
# 314            0
# 315            7
# 316            2
# 317            2
# 318            0
# 319            9
# 320            2
# 321            2
# 322            9
# 323            2
# 324            2
# 325            2
# 326            2
# 327            2
# 328            2
# 329            2
# 330            9
# 331           10
# 332            6
# 333            9
# 334            0
# 335           10
# 336            9
# 337            9
# 338            0
# 339           10
# 340            0
# 341            2
# 342           10
# 343            9
# 344            9
# 345            0
# 346            0
# 347            0
# 348            7
# 349            8
# 350            9
# 351            0
# 352            0
# 353           10
# 354            2
# 355            7
# 356            7
# 357            0
# 358            2
# 359            0
# 360            9
# 361            5
# 362            0
# 363            2
# 364            9
# 365            2
# 366            0
# 367            9
# 368            0
# 369            0
# 370            9
# 371            0
# 372            0
# 373            6
# 374            0
# 375            2
# 376            2
# 377           10
# 378            2
# 379            0
# 380            0
# 381            9
# 382            0
# 383            9
# 384            9
# 385            5
# 386            2
# 387            0
# 388            5
# 389            5
# 390            2
# 391            1
# 392            0
# 393            8
# 394           10
# 395            7
# 396            2
# 397            5
# 398            7
# 399            7
# 400            9
# 401            5
# 402            0
# 403            0
# 404            0
# 405            9
# 406            0
# 407            2
# 408            7
# 409            5
# 410            5
# 411            9
# 412            5
# 413            7
# 414            7
# 415           10
# 416            6
# 417            2
# 418            2
# 419            4
# 420            0
# 421            9
# 422            0
# 423            0
# 424            0
# 425            0
# 426            7
# 427            2
# 428            9
# 429            5
# 430            0
# 431            0
# 432            0
# 433            0
# 434            3
# 435            8
# 436            8
# 437           10
# 438            0
# 439            7
# 440            0
# 441            7
# 442            7
# 443            0
# 444            7
# 445            0
# 446            0
# 447            0
# 448            9
# 449            0
# 450            7
# 451            0
# 452            0
# 453            5
# 454            5
# 455            7
# 456            2
# 457            7
# 458            6
# 459            9
# 460            7
# 461            0
# 462            0
# 463            0
# 464            5
# 465            2
# 466            2
# 467            7
# 468            7
# 469            2
# 470            7
# 471            0
# 472            8
# 473            8
# 474            0
# 475            2
# 476            7
# 477           10
# 478            9
# 479            2
# 480            0
# 481            7
# 482           10
# 483            9
# 484            0
# 485            0
# 486            0
# 487            2
# 488            5
# 489            0
# 490            1
# 491            0
# 492            7
# 493            9
# 494            3
# 495            0
# 496            5
# 497            9
# 498            2
# 499            0
# 500            7
# 501            7
# 502            9
# 503            0
# 504            6
# 505            2
# 506            9
# 507            7
# 508            7
# 509            0
# 510            0
# 511            5
# 512            0
# 513           10
# 514            2
# 515            2
# 516            2
# 517            7
# 518            9
# 519            0
# 520            0
# 521            5
# 522            7
# 523            2
# 524            2
# 525            2
# 526            7
# 527            0
# 528            9
# 529            0
# 530            7
# 531            0
# 532            0
# 533            0
# 534            9
# 535            0
# 536            0
# 537            0
# 538            0
# 539            9
# 540            1
# 541            8
# 542            0
# 543           10
# 544            7
# 545            7
# 546            0
# 547            7
# 548            9
# 549            0
# 550            0
# 551            0
# 552            7
# 553            0
# 554            7
# 555            5
# 556            0
# 557            7
# 558            7
# 559            5
# 560            0
# 561            0
# 562            5
# 563            9
# 564            9
# 565            9
# 566            0
# 567            7
# 568            7
# 569            0
# 570            0
# 571            7
# 572            7
# 573            7
# 574            2
# 575            7
# 576            6
# 577            7
# 578            9
# 579            7
# 580            0
# 581            0
# 582            7
# 583            9
# 584            0
# 585            0
# 586            0
# 587            7
# 588            7
# 589            7
# 590            7
# 591            7
# 592            0
# 593            7
# 594            0
# 595            0
# 596            0
# 597            0
# 598            0
# 599            0
# 600            0
# 601            0
# 602            9
# 603            0
# 604            8
# 605            0
# 606            1
# 607           10
# 608            9
# 609            7
# 610            5
# 611            0
# 612            5
# 613            7
# 614            9
# 615            5
# 616            0
# 617            0
# 618            0
# 619            9
# 620            0
# 621            5
# 622            6
# 623            7
# 624            0
# 625            7
# 626            0
# 627            0
# 628            0
# 629            0
# 630            0
# 631            5
# 632            0
# 633            7
# 634            0
# 635            5
# 636            0
# 637            7
# 638            5
# 639            7
# 640            2
# 641            0
# 642            0
# 643            0
# 644            0
# 645            0
# 646            9
# 647            8
# 648            0
# 649           10
# 650            1
# 651            0
# 652            5
# 653            0
# 654            0
# 655            5
# 656            0
# 657            5
# 658            0
# 659            0
# 660            0
# 661            0
# 662            5
# 663            5
# 664            0
# 665            0
# 666            0
# 667            5
# 668            0
# 669            7
# 670            9
# 671            8
# 672            5
# 673            7
# 674            0
# 675            5
# 676            5
# 677            7
# 678            0
# 679            0
# 680            0
# 681            0
# 682            9
# 683            5
# 684            0
# 685            0
# 686            0
# 687            9
# 688            7
# 689            6
# 690            0
# 691            0
# 692            0
# 693            9
# 694            0
# 695            0
# 696            0
# 697            0
# 698            2
# 699            9
# 700            9
# 701            9
# 702           10
# 703            0
# 704           10
# 705            0
# 706            0
# 707            0
# 708           10
# 709            0
# 710            7
# 711            0
# 712            5
# 713            7
# 714            0
# 715            0
# 716            7
# 717            5
# 718            0
# 719            7
# 720            8
# 721           10
# 722            7
# 723            7
# 724            0
# 725            0
# 726            0
# 727            9
# 728            0
# 729            0
# 730            9
# 731            0
# 732            0
# 733            5
# 734            7
# 735            0
# 736            9
# 737            5
# 738            5
# 739            0
# 740            0
# 741            9
# 742            0
# 743            0
# 744            1
# 745            0
# 746            0
# 747            0
# 748            0
# 749            5
# 750            7
# 751            0
# 752            7
# 753            0
# 754           10
# 755            0
# 756            5
# 757            5
# 758            5
# 759            7
# 760            0
# 761            6
# 762            9
# 763            0
# 764            0
# 765            7
# 766            9
# 767            0
# 768            0
# 769            0
# 770            9
# 771            0
# 772            9
# 773            9
# 774            0
# 775            5
# 776            0
# 777            8
# 778            9
# 779            1
# 780            9
# 781            9
# 782           10
# 783            7
# 784            7
# 785            7
# 786            0
# 787            0
# 788            7
# 789            7
# 790            0
# 791            0
# 792            0
# 793            9
# 794            7
# 795            7
# 796            7
# 797            5
# 798            0
# 799            0
# 800            8
# 801            5
# 802            6
# 803            9
# 804            0
# 805            0
# 806            9
# 807            7
# 808            0
# 809            5
# 810            2
# 811            9
# 812            5
# 813            0
# 814            0
# 815            0
# 816            0
# 817            7
# 818            0
# 819            5
# 820            7
# 821            0
# 822            1
# 823            8
# 824            0
# 825           10
# 826            0
# 827            0
# 828            0
# 829            0
# 830            5
# 831            7
# 832            5
# 833            7
# 834            0
# 835            7
# 836            7
# 837            0
# 838            0
# 839            2
# 840            2
# 841            0
# 842            0
# 843            0
# 844            0
# 845            7
# 846            2
# 847            2
# 848            0
# 849            0
# 850            0
# 851            0
# 852           10
# 853            9
# 854            8
# 855            0
# 856            0
# 857            0
# 858            7
# 859            0
# 860            0
# 861            7
# 862            6
# 863            0
# 864            0
# 865            2
# 866            0
# 867            2
# 868            7
# 869            0
# 870            9
# 871            0
# 872            0
# 873            2
# 874            9
# 875            0
# 876            0
# 877            0
# 878            9
# 879            0
# 880            0
# 881            0
# 882            8
# 883           10
# 884            0
# 885            1
# 886            0
# 887            0
# 888            2
# 889            0
# 890            2
# 891            3
# 892            2
# 893            1
# 894            2
# 895            7
# 896           10
# 897            0
# 898            0
# 899            0
# 900            7
# 901            3
# 902            0
# 903            3
# 904           10
# 905            0
# 906            6
# 907            1
# 908            0
# 909            0
# 910            0
# 911           10
# 912            2
# 913            9
# 914            0
# 915            0
# 916            1
# 917            8

# %% [markdown]
# I'll isolate transactions without assigned transaction_type_id and category_id for manual review, after which they will be removed from the primary dataframe.

# %%
mask = ((sparkass['transaction_type_id'] == 0) & (sparkass['category_id'] == 0))
review_df = sparkass[mask].reset_index(drop=True)
sparkass_df = sparkass[~mask].reset_index(drop=True)
